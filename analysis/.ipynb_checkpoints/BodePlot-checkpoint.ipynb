# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import Image
Image(filename='IMG_0926.JPG')

# %%
run bodePlot.py

# %%
# Questions:
# 1. What does it mean for a first/second order system to be low pass? does it mean that higher frequency reference signals are 
# more difficult to track?

# %%
run model.py
